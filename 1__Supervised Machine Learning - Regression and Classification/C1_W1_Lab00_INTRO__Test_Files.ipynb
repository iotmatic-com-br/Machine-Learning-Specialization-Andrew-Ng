# %% [markdown]
# #Week 1 - Introductions to Machine Learning
#
# #Week 2 - Regression with multiple input variables
#
# #Week 3 - Classification

# %% [markdown]
# #**INICIAL**
#
# ## Resumo - Testes de arquivos
#
# ### Google Drive Setup

# %%
from google.colab import drive
import os

# Connect to my google drive
drive.mount('/content/drive')

# select folder inside drive
os.chdir('/content/drive/MyDrive/Colab__Machine_Learning_Specialization/1__Supervised Machine Learning - Regression and Classification')

# list files - optional
# !ls
# Out:
# Mounted at /content/drive
# archive
# betaversion
# C1_W1_Lab00_INTRO__Test_Files.ipynb
# C1_W1_Lab01_Python_Jupyter_Soln.ipynb
# C1_W1_Lab02_Model_Representation.ipynb
# C1_W1_Lab03_Cost_function_Soln.ipynb
# C1_W1_Lab04_Gradient_Descent_Soln.ipynb
# C1_W2_Lab01_Python_Numpy_Vectorization.ipynb
# C1_W2_Lab02_Multiple_Variable.ipynb
# C1_W2_Lab03_Feat_Scaling_LearningRate.ipynb
# C1_W2_Lab04_FeatEng_PolyReg.ipynb
# C1_W2_Lab05_Sklearn_Linear_Regression.ipynb
# C1_W2_Lab06_Sklearn_Grad_Desc.ipynb
# data
# data.txt
# deeplearning.mplstyle
# images
# lab_utils_common.py
# lab_utils_multi.py
# lab_utils_uni.py
# __pycache__
